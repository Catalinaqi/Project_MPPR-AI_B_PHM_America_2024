# %%
import sys
from pathlib import Path

# notebooks/ -> repo root
ROOT = Path.cwd().resolve()
print("The 'root path' (Root) from notebooks is...:", ROOT)

# If you run from notebooks/, ROOT is .../notebooks, then go up 1 level
if not (ROOT / "src").exists():
    print("Does the 'Root/src' path exist?...:", (ROOT / "src").exists())
    ROOT = ROOT.parent
    print("So the real 'root path' (Root) is...:", ROOT)

SRC = ROOT / "src"
print("The path to reach src is...:", SRC)
sys.path.insert(0, str(SRC))
# print("after insert", sys.path)

print("In conclusion, the root path is...:", ROOT)
print("In conclusion, the path to reach src is...:", SRC)
# Out:
# The 'root path' (Root) from notebooks is...: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\notebooks
# Does the 'Root/src' path exist?...: False
# So the real 'root path' (Root) is...: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024
# The path to reach src is...: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src
# In conclusion, the root path is...: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024
# In conclusion, the path to reach src is...: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src

# %%
import phm_america_2024
phm_america_2024.__file__
# Out:
# 'K:\\00_Code\\Manutenzione\\Project_MPPR-AI_B_PHM_America_2024\\src\\phm_america_2024\\__init__.py'

# %%
CORE = SRC / "phm_america_2024" / "core"
OUT = ROOT / "out"
LOG_UTIL_CORE = CORE / "logging_utils_core.py"
print(LOG_UTIL_CORE, LOG_UTIL_CORE.exists())
print("OUT path:", OUT, OUT.exists())
# Out:
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\core\logging_utils_core.py True
# OUT path: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out True

# %%
from phm_america_2024.core.logging_utils_core import build_log_file, init_logging, get_logger, _safe_name

# 0) Test _safe_name
run_name = _safe_name("Test Log File 123!@#$.log")
print("_safe_name:", run_name)

# 1) Create a log path (it does not create the file yet, it only creates the Path)
log_file = build_log_file(output_root=OUT, run_name=run_name)
print("build_log_file:", log_file)

# 2) Initialize logging: this creates out/logs and opens/creates the file
root_logger = init_logging(log_file=log_file, level="DEBUG")
print("init_logging:", root_logger)

__name__ = "__main__"

# 3) Get a logger and write logs
log = get_logger(__name__)

print("get_logger (debug call result):", log.debug("get_logger....: DEBUG from the notebook........."))
log.debug("get_logger....: DEBUG from the notebook")
log.info("get_logger....: INFO from the notebook")
log.warning("get_logger.....: WARNING from the notebook")
# Out:
# [11:15:49] [DEBUG] LOG_PHM_NORTH_AMERICA_2024 - Logging initialized. log_file=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\logs\test-log-file-123-log_20260206_111549.log level=DEBUG
# [11:15:49] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.__main__ - get_logger....: DEBUG from the notebook.........
# [11:15:49] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.__main__ - get_logger....: DEBUG from the notebook
# [11:15:49] [INFO] LOG_PHM_NORTH_AMERICA_2024.__main__ - get_logger....: INFO from the notebook
# [11:15:49] [WARNING] LOG_PHM_NORTH_AMERICA_2024.__main__ - get_logger.....: WARNING from the notebook
# _safe_name: test-log-file-123-log
# build_log_file: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\logs\test-log-file-123-log_20260206_111549.log
# init_logging: <Logger LOG_PHM_NORTH_AMERICA_2024 (DEBUG)>
# get_logger (debug call result): None
