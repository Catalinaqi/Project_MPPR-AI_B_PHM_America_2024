# %%
from pathlib import Path

# ---------- Root Path ----------------------------------------------
# Repository root from /notebooks
PROJECT_ROOT = Path.cwd().parent
print("PROJECT_ROOT:", PROJECT_ROOT.exists(), "| is:", PROJECT_ROOT)
# -------------------------------------------------------------------


# ---------- Sub Paths ----------
OUT_ROOT = PROJECT_ROOT / "out" # Directory for outputs
print("OUT_ROOT:", OUT_ROOT.exists(), "| is:", OUT_ROOT)
CONFIG_ROOT = PROJECT_ROOT / "config" # Directory for configuration
print("CONFIG_ROOT:", CONFIG_ROOT.exists(), "| is:", CONFIG_ROOT)

# ---------- Yaml Paths ----------
# Paths to specific YAML configuration files
pipeline_yaml_path = CONFIG_ROOT / "pipeline" / "classification_pipeline_config.yml"
print("pipeline_yaml_path exists?", pipeline_yaml_path.exists(), "| is:",pipeline_yaml_path)
# Path to dataset configuration YAML file
dataset_yaml_path = CONFIG_ROOT / "dataset" / "dataset_config.yml"
print("dataset_yaml_path exists?", dataset_yaml_path.exists(), "| is:",dataset_yaml_path)
# Out:
# PROJECT_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024
# OUT_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# CONFIG_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config
# pipeline_yaml_path exists? True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\pipeline\classification_pipeline_config.yml
# dataset_yaml_path exists? True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\dataset\dataset_config.yml

# %%
#################################### Parte 0 — Logging

from phm_america_2024.core.logging_utils_core import build_log_file, init_logging


log_file = build_log_file(output_root=OUT_ROOT, run_name="classification_manual_run")
init_logging(log_file=log_file, level="DEBUG")
# Out:
# [19:15:24] [DEBUG] LOG_PHM_NORTH_AMERICA_2024 - Logging initialized. log_file=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\logs\classification_manual_run_20260207_191524.log level=DEBUG
# <Logger LOG_PHM_NORTH_AMERICA_2024 (DEBUG)>

# %%
# Parte 1 — Cargar configuración (dataset + pipeline) y resolver variables

from phm_america_2024.pipelines.pipeline_context import build_context

ctx = build_context(
    dataset_config_path=str(dataset_yaml_path),
    pipeline_config_path=str(pipeline_yaml_path),
    output_root=str(OUT_ROOT)
)

cfg = ctx.cfg
variables = ctx.variables
output_root = ctx.output_root

# quick check
variables["join_key"], variables["label_col"], variables["x_train_path"]
# Out:
# [19:15:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.config.load_loader_config - Loading YAML: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\dataset\dataset_config.yml
# [19:15:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.config.load_loader_config - Loading YAML: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\pipeline\classification_pipeline_config.yml
# [19:15:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.seeds_utils_core - Global seed set: 42
# [19:15:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.pipelines.pipeline_context - Context built. output_root=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# [19:15:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.pipelines.pipeline_context - Variables keys=['join_key', 'label_col', 'output_root', 'time_col', 'x_test_path', 'x_train_path', 'x_validation_path', 'y_train_path']
# ('id', 'faulty', 'data/raw/train/X_train.csv')

# %%
# Parte 2 — Ejecutar Stage 2

from phm_america_2024.stages.stage2_understanding_runner_stages import run_stage2

stage2_out = run_stage2(cfg, variables, output_root)
# stage2_out contiene X_sample/Y_sample (muestra) y artefactos en out/
# Out:
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] cfg is: {'version': '1.0', 'pipeline': {'name': 'classification_pipeline', 'task': 'classification', 'objective': 'End-to-end CRISP-ML pipeline for supervised classification (categorical target). Stages 2→5. Generates report artifacts (PNG/JSON) and persists trained models.\n', 'variables': {'x_train_path': 'data/raw/train/X_train.csv', 'y_train_path': 'data/raw/train/Y_train.csv', 'x_test_path': 'data/raw/test/X_test.csv', 'x_validation_path': 'data/raw/validation/X_validation.csv', 'join_key': 'id', 'label_col': 'faulty', 'time_col': '${time_col}'}}, 'runtime': {'random_seed': 42, 'output_root': 'out', 'overwrite_artifacts': True}, 'stages': {'stage2_understanding': {'enabled': True, 'objective': 'Load CSV + describe structure + data quality assessment + EDA. Stage 2 MUST NOT modify data (report-only).\n', 'dataset_input': {'source_type': 'csv', 'path': 'data/raw/train/X_train.csv', 'labels_input': {'source_type': 'csv', 'path': 'data/raw/train/Y_train.csv'}, 'read_strategy': {'mode': 'sample', 'sample_rows': 200000, 'random_state': 42, 'chunk_size': 200000}}, 'output_policy': {'save_all_as_png': True, 'figures_dir': 'figures/stage2_understanding', 'tables_png_dir': 'tables_png/stage2_understanding', 'dpi': 150}, 'steps': {'step_2_1_data_acquisition': {'enabled': True, 'technique': 'data_acquisition', 'methods': {'load_csv': {'enabled': True, 'params': {'infer_datetime': False, 'parse_dates': []}}}}, 'step_2_2_describe_data': {'enabled': True, 'techniques': {'descriptive_statistics': {'enabled': True, 'methods': {'describe': {'enabled': True, 'params': {'include': 'all', 'numeric_only': False}}, 'min_max_mean_std': {'enabled': True, 'params': {'numeric_only': True}}}}, 'schema_inspection': {'enabled': True, 'methods': {'dtype_analysis': {'enabled': True}, 'cardinality_count': {'enabled': True, 'params': {'max_unique_to_report': 50}}, 'null_count': {'enabled': True}}}}}, 'step_2_3_data_quality_assessment': {'enabled': True, 'technique': 'data_quality_assessment', 'methods': {'missing_analysis': {'enabled': True, 'params': {'show_top_columns': 30}}, 'outlier_detection': {'enabled': True, 'params': {'method': 'iqr', 'iqr_k': 1.5, 'zscore_threshold': 3.0, 'numeric_only': True, 'max_columns': 30}}, 'duplicate_detection': {'enabled': True, 'params': {'subset': None, 'keep': 'first'}}, 'range_validation': {'enabled': False, 'params': {'rules_file': 'config/rules/ranges_quality_rules_config.yml', 'on_fail': 'report_only'}}, 'inconsistency_checks': {'enabled': False, 'params': {'rules_file': 'config/rules/logic_quality_rules_config.yml', 'on_fail': 'report_only'}}}}, 'step_2_4_eda': {'enabled': True, 'technique': 'eda', 'methods': {'histograms': {'enabled': True, 'params': {'numeric_only': True, 'max_columns': 20, 'bins': 30}}, 'boxplots': {'enabled': True, 'params': {'numeric_only': True, 'max_columns': 20}}, 'scatter_matrix': {'enabled': False, 'params': {'numeric_only': True, 'max_columns': 8, 'sample_rows': 10000}}, 'correlation_matrix': {'enabled': True, 'params': {'method': 'pearson', 'numeric_only': True, 'max_columns': 30}}, 'pca_exploratory': {'enabled': False, 'params': {'numeric_only': True, 'n_components': 2, 'sample_rows': 20000}}}}}}, 'stage3_preparation': {'enabled': True, 'objective': 'Prepare data for classification: selection + cleaning + transformations + (optional integration) + split + formatting. Generates artifacts.\n', 'output_policy': {'save_all_as_png': True, 'figures_dir': 'figures/stage3_preparation', 'tables_png_dir': 'tables_png/stage3_preparation'}, 'steps': {'step_3_1_data_selection': {'enabled': True, 'techniques': {'dataset_definition': {'enabled': True, 'methods': {'manual_include_exclude': {'enabled': False, 'params': {'include': [], 'exclude': []}}, 'drop_technical_columns': {'enabled': False, 'params': {'patterns': ['id', 'uuid', 'log']}}, 'population_filtering': {'enabled': Fals ...
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - === STAGE 2 START [run_stage2] ===
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] Stage2 paths resolved: x_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv (exists=True) | y_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv (exists=True)
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv mode=sample
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(sample): nrows=200000 shape=(200000, 8)
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv mode=sample
# [19:15:30] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(sample): nrows=200000 shape=(200000, 3)
# [19:15:30] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# [19:15:31] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - Saved table PNG: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\x_describe.png
# [19:15:31] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# [19:15:31] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - Saved table PNG: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\y_describe.png
# [19:15:31] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# [19:15:31] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - Saved table PNG: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\x_missing.png
# [19:15:31] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:32] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_trq_measured.png
# [19:15:32] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:32] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_oat.png
# [19:15:32] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:32] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_mgt.png
# [19:15:32] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:33] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_pa.png
# [19:15:33] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:33] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_ias.png
# [19:15:33] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:33] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_np.png
# [19:15:33] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [19:15:34] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\hist_ng.png
# [19:15:34] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - === STAGE 2 END [run_stage2] ===

# %%
# Parte 3 — Ejecutar Stage 3
from phm_america_2024.stages.stage3_preparation_runner_stages import run_stage3

stage3_out = run_stage3(cfg, variables, output_root)

stage3_out["X_train"].shape, stage3_out["X_valid"].shape
# Out:
# [19:15:36] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - === STAGE 3 START [run_stage3] ===
# [19:15:36] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Stage3 resolved paths: x_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv (exists=True) y_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv (exists=True)
# [19:15:36] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv mode=full
# [19:15:37] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(full): shape=(742625, 8)
# [19:15:37] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv mode=full
# [19:15:37] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(full): shape=(742625, 3)
# [19:15:37] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - join_x_y: join_key=id before=((742625, 8), (742625, 3)) after=(742625, 10)
# [19:15:37] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Dropping column after join: trq_margin
# [19:15:37] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Dropping column after join: id
# [19:15:38] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.split_service_features - split_holdout: train=(594100, 8) valid=(148525, 8) label=faulty stratify=True
# [19:15:38] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.transforms_service_features - Built numeric preprocessor: imputer=median scaling=standard features=7
# [19:15:38] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Stage3 outputs: X_train=(594100, 7) y_train=(594100,) X_valid=(148525, 7) y_valid=(148525,) features=7
# [19:15:38] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - === STAGE 3 END [run_stage3] ===
# ((594100, 7), (148525, 7))

# %%
# Parte 4 — Ejecutar Stage 4
from phm_america_2024.stages.stage4_modeling_runner_stages import run_stage4

stage4_out = run_stage4(cfg, stage3_out, output_root)

stage4_out["best_model_name"], stage4_out["best_model_path"]
# Out:
# [19:17:31] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage4_modeling_runner_stages - === STAGE 4 START ===
# [19:17:31] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.model_registry_models - Enabled estimators: ['decision_tree_classifier', 'random_forest_classifier']
# [19:17:31] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.train_service_models - Training: decision_tree_classifier
# [19:17:40] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.train_service_models - Trained: decision_tree_classifier
# [19:17:40] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.train_service_models - Training: random_forest_classifier
# [19:18:00] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.train_service_models - Trained: random_forest_classifier
# [19:18:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.evaluate_service_models - Eval: acc=0.9971 f1_weighted=0.9971
# [19:18:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.models.evaluate_service_models - Eval: acc=0.9994 f1_weighted=0.9994
# [19:18:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage4_modeling_runner_stages - Best model: random_forest_classifier (f1_weighted=0.9994)
# [19:18:01] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\models
# [19:18:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage4_modeling_runner_stages - Saved best model: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\models\best_model.joblib
# [19:18:01] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# [19:18:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - write_json: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\metrics.json
# [19:18:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage4_modeling_runner_stages - === STAGE 4 END ===
# ('random_forest_classifier',
#  'K:\\00_Code\\Manutenzione\\Project_MPPR-AI_B_PHM_America_2024\\out\\models\\best_model.joblib')

# %%
# Parte 5 — Ejecutar Stage 5
from phm_america_2024.stages.stage5_evaluation_runner_stages import run_stage5

stage5_out = run_stage5(cfg, stage3_out, stage4_out, output_root)

stage5_out
# Out:
# [19:18:15] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage5_evaluation_runner_stages - === STAGE 5 START ===
# [19:18:15] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.interpretation.explain_service_interpretation - feature_importance computed: top_k=30
# [19:18:44] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.interpretation.explain_service_interpretation - permutation_importance computed: top_k=30 n_repeats=10
# [19:18:44] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.interpretation.explain_service_interpretation - confusion_matrix computed normalize=true
# [19:18:44] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage5_evaluation_and_interpretation
# [19:18:44] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage5_evaluation_and_interpretation\confusion_matrix.png
# [19:18:44] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# [19:18:44] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - write_json: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\interpretation.json
# [19:18:44] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage5_evaluation_runner_stages - Saved interpretation: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\interpretation.json
# [19:18:44] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage5_evaluation_runner_stages - === STAGE 5 END ===
# {'interpretation_json': 'K:\\00_Code\\Manutenzione\\Project_MPPR-AI_B_PHM_America_2024\\out\\interpretation.json'}
