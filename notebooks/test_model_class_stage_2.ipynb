# %%
from pathlib import Path

# ---------- Root Path ----------------------------------------------
# Repository root from /notebooks
PROJECT_ROOT = Path.cwd().parent
print("PROJECT_ROOT:", PROJECT_ROOT.exists(), "| is:", PROJECT_ROOT)
# -------------------------------------------------------------------


# ---------- Sub Paths ----------
OUT_ROOT = PROJECT_ROOT / "out" # Directory for outputs
print("OUT_ROOT:", OUT_ROOT.exists(), "| is:", OUT_ROOT)
CONFIG_ROOT = PROJECT_ROOT / "config" # Directory for configuration
print("CONFIG_ROOT:", CONFIG_ROOT.exists(), "| is:", CONFIG_ROOT)

# ---------- Yaml Paths ----------
# Paths to specific YAML configuration files
pipeline_yaml_path = CONFIG_ROOT / "pipeline" / "classification_pipeline_config.yml"
print("pipeline_yaml_path exists?", pipeline_yaml_path.exists(), "| is:",pipeline_yaml_path)
# Path to dataset configuration YAML file
dataset_yaml_path = CONFIG_ROOT / "dataset" / "dataset_config.yml"
print("dataset_yaml_path exists?", dataset_yaml_path.exists(), "| is:",dataset_yaml_path)
# Out:
# PROJECT_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024
# OUT_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# CONFIG_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config
# pipeline_yaml_path exists? True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\pipeline\classification_pipeline_config.yml
# dataset_yaml_path exists? True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\dataset\dataset_config.yml

# %%
#################################### Parte 0 — Logging

from phm_america_2024.core.logging_utils_core import build_log_file, init_logging


log_file = build_log_file(output_root=OUT_ROOT, run_name="classification_manual_run")
init_logging(log_file=log_file, level="DEBUG")
# Out:
# [20:07:46] [DEBUG] LOG_PHM_NORTH_AMERICA_2024 - Logging initialized. log_file=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\logs\classification_manual_run_20260211_200746.log level=DEBUG
# <Logger LOG_PHM_NORTH_AMERICA_2024 (DEBUG)>

# %%
# Parte 1 — Cargar configuración (dataset + pipeline) y resolver variables

from phm_america_2024.pipelines.pipeline_context import build_context

ctx = build_context(
    dataset_config_path=str(dataset_yaml_path),
    pipeline_config_path=str(pipeline_yaml_path),
    output_root=str(OUT_ROOT)
)

cfg = ctx.cfg
variables = ctx.variables
output_root = ctx.output_root

# quick check
variables["join_key"], variables["label_col"], variables["x_train_path"]
# Out:
# [20:07:51] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.config.load_loader_config - Loading YAML: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\dataset\dataset_config.yml
# [20:07:51] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.config.load_loader_config - Loading YAML: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\pipeline\classification_pipeline_config.yml
# [20:07:51] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.seeds_utils_core - Global seed set: 42
# [20:07:51] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.pipelines.pipeline_context - Context built. output_root=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# [20:07:51] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.pipelines.pipeline_context - Variables keys=['join_key', 'label_col', 'output_root', 'time_col', 'x_test_path', 'x_train_path', 'x_validation_path', 'y_train_path']
# ('id', 'faulty', 'data/raw/train/X_train.csv')

# %%
# Parte 2 — Ejecutar Stage 2

from phm_america_2024.stages.stage2_understanding_runner_stages import run_stage2

stage2_out = run_stage2(cfg, variables, output_root)
# stage2_out contiene X_sample/Y_sample (muestra) y artefactos en out/
# Out:
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] data from the root of the yaml: version [] and pipeline [] (cfg):
# {
#   "pipeline": {
#     "name": "classification_pipeline",
#     "objective": "End-to-end CRISP-ML pipeline for supervised classification (categorical target). Stages 2→5. Generates report artifacts (PNG/JSON) and persists trained models.\n",
#     "task": "classification",
#     "variables": {
#       "join_key": "id",
#       "label_col": "faulty",
#       "time_col": "${time_col}",
#       "x_test_path": "data/raw/test/X_test.csv",
#       "x_train_path": "data/raw/train/X_train.csv",
#       "x_validation_path": "data/raw/validation/X_validation.csv",
#       "y_train_path": "data/raw/train/Y_train.csv"
#     }
#   },
#   "runtime": {
#     "output_root": "out",
#     "overwrite_artifacts": true,
#     "random_seed": 42
#   },
#   "stages": {
#     "stage2_understanding": {
#       "dataset_input": {
#         "csv_params": {
#           "decimal": ".",
#           "encoding": "utf-8",
#           "low_memory": false,
#           "sep": ","
#         },
#         "labels_input": {
#           "path": "data/raw/train/Y_train.csv",
#           "source_type": "csv"
#         },
#         "path": "data/raw/train/X_train.csv",
#         "read_strategy": {
#           "chunk_size": 200000,
#           "mode": "full",
#           "random_state": 42,
#           "sample_rows": 200000
#         },
#         "source_type": "csv"
#       },
#       "enabled": true,
#       "objective": "Load CSV + describe structure + data quality assessment + EDA. Stage 2 MUST NOT modify data (report-only).\n",
#       "output_policy": {
#         "align": "left",
#         "dpi": 150,
#         "figures_dir": "figures/stage2_understanding",
#         "float_fmt": "{:.3f}",
#         "max_rows": 60,
#         "save_all_as_png": true,
#         "tables_png_dir": "tables_png/stage2_understanding"
#       },
#       "steps": {
#         "step_2_1_data_acquisition": {
#           "enabled": true,
#           "methods": {
#             "load_csv": {
#               "enabled": true,
#               "params": {
#                 "infer_datetime": false,
#                 "parse_dates": []
#               }
#             }
#           },
#           "name": "step_2_1_data_acquisition",
#           "technique": "data_acquisition"
#         },
#         "step_2_2_describe_data": {
#           "enabled": true,
#           "name": "step_2_2_describe_data",
#           "techniques": {
#             "descriptive_statistics": {
#               "enabled": true,
#               "methods": {
#                 "describe": {
#                   "enabled": true,
#                   "params": {
#                     "include": "all",
#                     "numeric_only": false
#                   }
#                 },
#                 "min_max_mean_std": {
#                   "enabled": true,
#                   "params": {
#                     "numeric_only": true
#                   }
#                 }
#               }
#             },
#             "schema_inspection": {
#               "enabled": true,
#               "methods": {
#                 "cardinality_count": {
#                   "enabled": true,
#                   "params": {
#                     "max_unique_to_report": 50
#                   }
#                 },
#                 "dtype_analysis": {
#                   "enabled": true
#                 },
#                 "null_count": {
#                   "enabled": true
#                 }
#               }
#             }
#           }
#         },
#         "step_2_3_data_quality_assessment": {
#           "enabled": true,
#           "methods": {
#             "duplicate_detection": {
#               "enabled": true,
#               "params": {
#                 "keep": "first",
#                 "subset": null
#               }
#             },
#             "inconsistency_checks": {
#               "enabled": false,
#               "params": {
#                 "on_fail": "report_only",
#                 "rules_file": "config/rules/logic_quality_rules_config.yml"
#               }
#             },
#             "missing_analysis": {
#               "enabled": true,
#               "params": {
#                 "show_top_columns": 30
#               }
#             },
#             "outlier_detection": {
#               "enabled": true,
#               "params": {
#                 "iqr_k": 1.5,
#                 "max_columns": 30,
#                 "method": "iqr",
#                 "numeric_only": true,
#                 "zscore_threshold": 3.0
#               }
#             },
#             "percentile_analysis": {
#               "enabled": true,
#               "params": {
#                 "columns": [
#                   "pa"
#                 ],
#                 "percentiles": [
#                   0.01,
#                   0.05,
#                   0.95,
#                   0.99,
#                   0.999
#                 ]
#               }
#             },
#             "range_validation": {
#               "enabled": false,
#               "params": {
#                 "on_fail": "report_only",
#                 "rules_file": "config/rules/ranges_quality_rules_config.yml"
#               }
#             }
#           },
#           "name": "step_2_3_data_quality_assessment",
#           "technique": "data_quality_assessment"
#         },
#         "step_2_4_eda": {
#           "enabled": true,
#           "methods": {
#             "boxplots": {
#               "enabled": true,
#               "params": {
#                 "max_columns": 20,
#                 "numeric_only": true
#               }
#             },
#             "correlation_matrix": {
#               "enabled": true,
#               "params": {
#                 "max_columns": 30,
#                 "method": "pearson",
#                 "numeric_only": true
#               }
#             },
#             "histograms": {
#               "enabled": true,
#               "params": {
#                 "bins": 30,
#                 "max_columns": 20,
#                 "numeric_only": true
#               }
#             },
#             "pca_exploratory": {
#               "enabled": false,
#               "params": {
#                 "n_components": 2,
#                 "numeric_only": true,
#                 "sample_rows": 20000
#               }
#             },
#             "scatter_matrix": {
#               "enabled": false,
#               "params": {
#                 "max_columns": 8,
#                 "numeric_only": true,
#                 "sample_rows": 10000
#               }
#             }
#           },
#           "name": "step_2_4_eda",
#           "technique": "eda"
#         }
#       }
#     },
#     "stage3_preparation": {
#       "enabled": true,
#       "objective": "Prepare data for classification: selection + cleaning + transformations + (optional integration) + split + formatting. Generates artifacts.\n",
#       "output_policy": {
#         "figures_dir": "figures/stage3_preparation",
#         "save_all_as_png": true,
#         "tables_png_dir": "tables_png/stage3_preparation"
#       },
#       "steps": {
#         "step_3_1_data_selection": {
#           "enabled": true,
#           "techniques": {
#             "dataset_definition": {
#               "enabled": false,
#               "methods": {
#                 "drop_technical_columns": {
#                   "enabled": false,
#                   "params": {
#                     "patterns": [
#                       "uuid",
#                       "log"
#                     ]
#                   }
#                 },
#                 "manual_include_exclude": {
#                   "enabled": false,
#                   "params": {
#                     "exclude": [],
#                     "include": []
#                   }
#                 },
#                 "population_filtering": {
#                   "enabled": false,
#                   "params": {
#                     "rules_file": "config/rules/logic_quality_rules_config.yml"
#                   }
#                 }
#               }
#             },
#             "feature_selection": {
#               "enabled": true,
#               "methods": {
#                 "business_rule_filtering": {
#                   "enabled": false,
#                   "params": {
#                     "rules_file": "config/rules/logic_quality_rules_config.yml"
#                   }
#                 },
#                 "remove_constant_features": {
#                   "enabled": true,
#                   "params": {
#                     "threshold_unique": 1
#                   }
#                 },
#                 "remove_duplicate_features": {
#                   "enabled": true,
#                   "params": {
#                     "strategy": "exact"
#                   }
#                 },
#                 "semantic_based_selection": {
#                   "enabled": false,
#                   "params": {
#                     "keep": []
#                   }
#                 }
#               }
#             }
#           }
#         },
#         "step_3_2_data_cleaning": {
#           "enabled": true,
#           "techniques": {
#             "duplicate_handling": {
#               "enabled": true,
#               "method": {
#                 "exact_duplicates": {
#                   "enabled": true,
#                   "params": {
#                     "keep": "first",
#                     "subset": null
#                   }
#                 }
#               }
#             },
#             "missing_data_handling": {
#               "enabled": true,
#               "methods": {
#                 "median_imputation": {
#                   "enabled": false,
#                   "params": {
#                     "numeric_only": true
#                   }
#                 }
#               },
#               "selection_policy": {
#                 "numeric_imputer": "median_imputation"
#               }
#             }
#           }
#         },
#         "step_3_3_data_transformation": {
#           "enabled": true,
#           "techniques": {
#             "encoding": {
#               "enabled": false,
#               "methods": {
#                 "frequency_encoding": {
#                   "enabled": false,
#                   "params": {
#                     "min_freq": 1
#                   }
#                 },
#                 "one_hot_encoding": {
#                   "enabled": true,
#                   "params": {
#                     "handle_unknown": "ignore"
#                   }
#                 },
#                 "ordinal_encoding": {
#                   "enabled": false,
#                   "params": {}
#                 }
#               },
#               "selection_policy": {
#                 "categorical_encoding": "one_hot_encoding"
#               }
#             },
#             "feature_engineering": {
#               "enabled": false,
#               "methods": {
#                 "aggregations": {
#                   "enabled": false,
#                   "params": {
#                     "agg_map": {},
#                     "groupby_cols": []
#                   }
#                 },
#                 "interactions": {
#                   "enabled": false,
#                   "params": {}
#                 },
#                 "polynomial_features": {
#                   "enabled": false,
#                   "params": {
#                     "degree": 2
#                   }
#                 },
#                 "ratios": {
#                   "enabled": false,
#                   "params": {
#                     "definitions": []
#                   }
#                 }
#               }
#             },
#             "feature_scaling": {
#               "enabled": true,
#               "methods": {
#                 "robust_scaling": {
#                   "enabled": false,
#                   "params": {}
#                 },
#                 "standard_scaling": {
#                   "enabled": true,
#                   "params": {}
#                 }
#               },
#               "selection_policy": {
#                 "scaling_method": "standard_scaling"
#               }
#             }
#           }
#         },
#         "step_3_4_data_integration": {
#           "enabled": false
#         },
#         "step_3_5_data_formatting": {
#           "enabled": true,
#           "techniques": {
#             "data_split": {
#               "enabled": true,
#               "methods": {
#                 "holdout": {
#                   "enabled": true,
#                   "params": {
#                     "random_state": 42,
#                     "stratify": true,
#                     "test_size": 0.2
#                   }
#                 },
#                 "train_val_test": {
#                   "enabled": false,
#                   "params": {
#                     "random_state": 42,
#                     "stratify": true,
#                     "test": 0.2,
#                     "train": 0.7,
#                     "val": 0.1
#                   }
#                 }
#               },
#               "selection_policy": {
#                 "split_method": "holdout"
#               }
#             },
#             "dataset_formatting": {
#               "enabled": true,
#               "methods": {
#                 "join_x_y": {
#                   "enabled": true,
#                   "params": {
#                     "drop_after_join": [
#                       "trq_margin",
#                       "id"
#                     ],
#                     "join_key": "id",
#                     "label_col": "faulty",
#                     "x_path": "data/raw/train/X_train.csv",
#                     "y_path": "data/raw/train/Y_train.csv"
#                   }
#                 },
#                 "sparse_dense_format": {
#                   "enabled": true,
#                   "params": {
#                     "format": "sparse"
#                   }
#                 },
#                 "type_casting": {
#                   "enabled": true,
#                   "params": {}
#                 },
#                 "x_y_separation": {
#                   "enabled": true,
#                   "params": {}
#                 }
#               }
#             }
#           }
#         }
#       }
#     },
#     "stage4_modeling": {
#       "enabled": true,
#       "objective": "Phase 4 (Modeling) for classification: algorithm selection, training, test design (CV/holdout), hyperparameter tuning, and evaluation metrics.\n",
#       "output_policy": {
#         "figures_dir": "figures/stage4_modeling",
#         "metrics_file": "metrics.json",
#         "models_dir": "models",
#         "save_all_as_png": true,
#         "tables_png_dir": "tables_png/stage4_modeling"
#       },
#       "steps": {
#         "step_4_1_algorithm_selection": {
#           "enabled": true,
#           "methods": {
#             "decision_tree_classifier": {
#               "enabled": true,
#               "params": {
#                 "random_state": 42
#               }
#             },
#             "knn_classifier": {
#               "enabled": false,
#               "params": {}
#             },
#             "naive_bayes_classifier": {
#               "enabled": false,
#               "params": {}
#             },
#             "random_forest_classifier": {
#               "enabled": true,
#               "params": {
#                 "n_estimators": 100,
#                 "n_jobs": -1,
#                 "random_state": 42
#               }
#             },
#             "svm_classifier": {
#               "enabled": false,
#               "params": {}
#             }
#           },
#           "technique": "algorithm_selection"
#         },
#         "step_4_2_model_training": {
#           "enabled": true,
#           "methods": {
#             "fit": {
#               "enabled": true,
#               "params": {
#                 "fit_best_only": true,
#                 "store_all_models": true
#               }
#             },
#             "hyperparameter_tuning": {
#               "enabled": false,
#               "grids": {
#                 "decision_tree_classifier": {
#                   "max_depth": [
#                     3,
#                     5,
#                     10,
#                     null
#                   ],
#                   "min_samples_split": [
#                     2,
#                     5,
#                     10
#                   ]
#                 },
#                 "knn_classifier": {
#                   "n_neighbors": [
#                     3,
#                     5,
#                     7,
#                     11
#                   ],
#                   "weights": [
#                     "uniform",
#                     "distance"
#                   ]
#                 },
#                 "naive_bayes_classifier": {
#                   "var_smoothing": [
#                     1e-09,
#                     1e-08
#                   ]
#                 },
#                 "random_forest_classifier": {
#                   "max_depth": [
#                     null,
#                     10,
#                     20
#                   ],
#                   "min_samples_split": [
#                     2,
#                     5
#                   ],
#                   "n_estimators": [
#                     100,
#                     200
#                   ]
#                 },
#                 "svm_classifier": {
#                   "C": [
#                     0.1,
#                     1,
#                     10
#                   ],
#                   "kernel": [
#                     "rbf",
#                     "linear"
#                   ]
#                 }
#               },
#               "params": {
#                 "n_iter": 30,
#                 "refit": true,
#                 "scoring": "f1_weighted",
#                 "strategy": "grid"
#               }
#             }
#           },
#           "technique": "model_training"
#         },
#         "step_4_3_test_design": {
#           "enabled": true,
#           "methods": {
#             "cross_validation": {
#               "enabled": false,
#               "params": {
#                 "cv_folds": 5,
#                 "random_state": 42,
#                 "shuffle": true
#               }
#             },
#             "holdout": {
#               "enabled": true,
#               "params": {
#                 "random_state": 42,
#                 "stratify": true,
#                 "test_size": 0.2
#               }
#             }
#           },
#           "technique": "test_design"
#         },
#         "step_4_4_model_evaluation": {
#           "enabled": true,
#           "metrics": {
#             "accuracy": {
#               "enabled": true,
#               "params": {}
#             },
#             "f1_score": {
#               "enabled": true,
#               "params": {
#                 "average": "weighted"
#               }
#             }
#           },
#           "technique": "model_evaluation"
#         }
#       }
#     },
#     "stage5_evaluation_and_interpretation": {
#       "enabled": true,
#       "objective": "Phase 5 (Evaluation & Interpretation): translate model results into actionable knowledge, validate business value, audit the pipeline, and decide next steps.\n",
#       "output_policy": {
#         "figures_dir": "figures/stage5_evaluation_and_interpretation",
#         "metrics_file": "metrics.json",
#         "save_all_as_png": true,
#         "tables_png_dir": "tables_png/stage5_evaluation_and_interpretation"
#       },
#       "steps": {
#         "step_5_1_interpretation": {
#           "enabled": true,
#           "methods": {
#             "coefficients": {
#               "enabled": false,
#               "params": {
#                 "include_models": [
#                   "svm_linear",
#                   "logistic_like_if_any"
#                 ],
#                 "top_k": 30
#               }
#             },
#             "confusion_matrix_analysis": {
#               "enabled": true,
#               "params": {
#                 "include_class_report": true,
#                 "normalize": "true"
#               }
#             },
#             "feature_importance": {
#               "enabled": true,
#               "params": {
#                 "normalize": true,
#                 "top_k": 30
#               }
#             },
#             "permutation_importance": {
#               "enabled": true,
#               "params": {
#                 "n_repeats": 10,
#                 "random_state": 42
#               }
#             }
#           },
#           "technique": "interpretation"
#         },
#         "step_5_2_business_evaluation": {
#           "enabled": true,
#           "methods": {
#             "baseline_comparison": {
#               "enabled": true,
#               "params": {
#                 "baseline": "majority_class"
#               }
#             },
#             "business_kpis": {
#               "enabled": false,
#               "params": {
#                 "currency": "EUR",
#                 "kpi_rules_file": "config/rules/business_kpi_rules_config.yml"
#               }
#             },
#             "compare_models": {
#               "enabled": true,
#               "params": {
#                 "rank_by": [
#                   "f1_weighted",
#                   "accuracy"
#                 ]
#               }
#             }
#           },
#           "technique": "business_evaluation"
#         },
#         "step_5_3_process_audit": {
#           "enabled": true,
#           "methods": {
#             "leakage_detection": {
#               "enabled": true,
#               "params": {
#                 "check_time_leakage": false,
#                 "label_col": "faulty",
#                 "time_col": "${time_col}"
#               }
#             },
#             "pipeline_review": {
#               "enabled": false,
#               "params": {
#                 "checklist_file": "config/rules/pipeline_review_checklist.yml"
#               }
#             },
#             "reproducibility_check": {
#               "enabled": true,
#               "params": {
#                 "require_config_snapshot": true,
#                 "require_seed": true
#               }
#             }
#           },
#           "technique": "process_audit"
#         },
#         "step_5_4_decision_making": {
#           "enabled": false,
#           "methods": {
#             "go_no_go_decision": {
#               "enabled": true,
#               "params": {
#                 "min_accuracy": 0.7,
#                 "min_f1_weighted": 0.65
#               }
#             },
#             "human_in_the_loop": {
#               "enabled": true,
#               "params": {
#                 "require_manual_signoff": true
#               }
#             },
#             "iterate_model": {
#               "enabled": true,
#               "params": {
#                 "enable_backloop_to_stage": 4
#               }
#             }
#           },
#           "technique": "decision_making"
#         },
#         "step_5_5_submission_export": {
#           "enabled": false,
#           "params": {
#             "id_field": "id",
#             "output_dir": "submissions",
#             "test_filename": "submission.jso",
#             "validation_filename": "validation_submission.jso"
#           },
#           "technique": "submission_export"
#         }
#       }
#     }
#   },
#   "version": "1.0"
# }
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] data from the root of the yaml: variables ... | runtime [] | stages []:
# {
#   "join_key": "id",
#   "label_col": "faulty",
#   "output_root": "K:\\00_Code\\Manutenzione\\Project_MPPR-AI_B_PHM_America_2024\\out",
#   "time_col": "${time_col}",
#   "x_test_path": "data/raw/test/X_test.csv",
#   "x_train_path": "data/raw/train/X_train.csv",
#   "x_validation_path": "data/raw/validation/X_validation.csv",
#   "y_train_path": "data/raw/train/Y_train.csv"
# }
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] output path is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] params={"cfg":{"pipeline":{"name":"classification_pipeline","objective":"End-to-end CRISP-ML pipeline for supervised classification (categorical target). Stages 2→5. Generates report artifacts (PNG/JSON) and persists trained models.\n","task":"classification","variables":{"join_key":"id","label_col":"faulty","time_col":"${time_col}","x_test_path":"data/raw/test/X_test.csv","x_train_path":"data/raw/train/X_train.csv","x_validation_path":"data/raw/validation/X_validation.csv","y_train_path":"data/raw/train/Y_train.csv"}},"runtime":{"output_root":"out","overwrite_artifacts":true,"random_seed":42},"stages":{"stage2_understanding":{"dataset_input":{"csv_params":{"decimal":".","encoding":"utf-8","low_memory":false,"sep":","},"labels_input":{"path":"data/raw/train/Y_train.csv","source_type":"csv"},"path":"data/raw/train/X_train.csv","read_strategy":{"chunk_size":200000,"mode":"full","random_state":42,"sample_rows":200000},"source_type":"csv"},"enabled":true,"objective":"Load CSV + describe structure + data quality assessment + EDA. Stage 2 MUST NOT modify data (report-only).\n","output_policy":{"align":"left","dpi":150,"figures_dir":"figures/stage2_understanding","float_fmt":"{:.3f}","max_rows":60,"save_all_as_png":true,"tables_png_dir":"tables_png/stage2_understanding"},"steps":{"step_2_1_data_acquisition":{"enabled":true,"methods":{"load_csv":{"enabled":true,"params":{"infer_datetime":false,"parse_dates":[]}}},"name":"step_2_1_data_acquisition","technique":"data_acquisition"},"step_2_2_describe_data":{"enabled":true,"name":"step_2_2_describe_data","techniques":{"descriptive_statistics":{"enabled":true,"methods":{"describe":{"enabled":true,"params":{"include":"all","numeric_only":false}},"min_max_mean_std":{"enabled":true,"params":{"numeric_only":true}}}},"schema_inspection":{"enabled":true,"methods":{"cardinality_count":{"enabled":true,"params":{"max_unique_to_report":50}},"dtype_analysis":{"enabled":true},"null_count":{"enabled":true}}}}},"step_2_3_data_quality_assessment":{"enabled":true,"methods":{"duplicate_detection":{"enabled":true,"params":{"keep":"first","subset":null}},"inconsistency_checks":{"enabled":false,"params":{"on_fail":"report_only","rules_file":"config/rules/logic_quality_rules_config.yml"}},"missing_analysis":{"enabled":true,"params":{"show_top_columns":30}},"outlier_detection":{"enabled":true,"params":{"iqr_k":1.5,"max_columns":30,"method":"iqr","numeric_only":true,"zscore_threshold":3.0}},"percentile_analysis":{"enabled":true,"params":{"columns":["pa"],"percentiles":[0.01,0.05,0.95,0.99,0.999]}},"range_validation":{"enabled":false,"params":{"on_fail":"report_only","rules_file":"config/rules/ranges_quality_rules_config.yml"}}},"name":"step_2_3_data_quality_assessment","technique":"data_quality_assessment"},"step_2_4_eda":{"enabled":true,"methods":{"boxplots":{"enabled":true,"params":{"max_columns":20,"numeric_only":true}},"correlation_matrix":{"enabled":true,"params":{"max_columns":30,"method":"pearson","numeric_only":true}},"histograms":{"enabled":true,"params":{"bins":30,"max_columns":20,"numeric_only":true}},"pca_exploratory":{"enabled":false,"params":{"n_components":2,"numeric_only":true,"sample_rows":20000}},"scatter_matrix":{"enabled":false,"params":{"max_columns":8,"numeric_only":true,"sample_rows":10000}}},"name":"step_2_4_eda","technique":"eda"}}},"stage3_preparation":{"enabled":true,"objective":"Prepare data for classification: selection + cleaning + transformations + (optional integration) + split + formatting. Generates artifacts.\n","output_policy":{"figures_dir":"figures/stage3_preparation","save_all_as_png":true,"tables_png_dir":"tables_png/stage3_preparation"},"steps":{"step_3_1_data_selection":{"enabled":true,"techniques":{"dataset_definition":{"enabled":false,"methods":{"drop_technical_columns":{"enabled":false,"params":{"patterns":["uuid","log"]}},"manual_include_exclude":{"e ...
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - === STAGE 2 START [run_stage2] ===
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - [run_stage2] Stage2 paths resolved: x_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv (exists=True) | y_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv (exists=True)
# [20:07:56] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv mode=full
# [20:07:57] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(full): shape=(742625, 8)
# [20:07:57] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv mode=full
# [20:07:58] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(full): shape=(742625, 3)
# [20:07:58] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [safe_describe] start: rows=742625 cols=8 numeric_only=False include=all
# [20:07:58] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [safe_describe] end: produced describe table shape=(8, 8)
# [20:07:58] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [safe_describe] start: rows=742625 cols=3 numeric_only=False include=all
# [20:07:59] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [safe_describe] end: produced describe table shape=(8, 3)
# [20:07:59] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic][Stage2/X] Case1: describe-like detected -> transposed. in=(8, 8) out=(8, 9)
# [20:07:59] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic][Stage2/X] ordered rows by original_columns (matched=8)
# [20:07:59] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic][Stage2/Y] Case1: describe-like detected -> transposed. in=(8, 3) out=(3, 9)
# [20:07:59] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic][Stage2/Y] ordered rows by original_columns (matched=3)
# [20:07:59] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:07:59] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_x_descriptive.png (rows=8 cols=9)
# [20:07:59] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:00] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_y_descriptive.png (rows=3 cols=9)
# [20:08:00] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.quality_rules_utils_data - [numeric_cols] selected 7/8 numeric cols (excluded=['id'])
# [20:08:00] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.quality_rules_utils_data - [numeric_cols] selected 2/3 numeric cols (excluded=['id'])
# [20:08:00] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(7, 4) out=(7, 5)
# [20:08:00] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_x_min_max_mean_std.png (rows=7 cols=5)
# [20:08:01] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(2, 4) out=(2, 5)
# [20:08:01] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_y_min_max_mean_std.png (rows=2 cols=5)
# [20:08:01] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(8, 1) out=(8, 2)
# [20:08:01] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_x_dtype_analysis.png (rows=8 cols=2)
# [20:08:01] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(3, 1) out=(3, 2)
# [20:08:01] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:01] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_y_dtype_analysis.png (rows=3 cols=2)
# [20:08:02] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(8, 1) out=(8, 2)
# [20:08:02] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:02] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_x_cardinality.png (rows=8 cols=2)
# [20:08:02] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(3, 1) out=(3, 2)
# [20:08:02] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:03] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_y_cardinality.png (rows=3 cols=2)
# [20:08:03] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(8, 2) out=(8, 3)
# [20:08:03] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:03] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_x_missing.png (rows=8 cols=3)
# [20:08:03] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(3, 2) out=(3, 3)
# [20:08:03] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:03] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_2_describe_data_y_missing.png (rows=3 cols=3)
# [20:08:03] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.quality_rules_utils_data - [numeric_cols] selected 7/8 numeric cols (excluded=['id'])
# [20:08:03] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.quality_rules_utils_data - [numeric_cols] selected 2/3 numeric cols (excluded=['id'])
# [20:08:03] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(7, 5) out=(7, 6)
# [20:08:03] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:04] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_3_data_quality_assessment_x_percentiles.png (rows=7 cols=6)
# [20:08:04] [WARNING] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [as_table_by_column_heuristic] Case2b: index moved into 'NameColumn'. in=(2, 5) out=(2, 6)
# [20:08:04] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding
# K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\src\phm_america_2024\reporting\artifacts_service_reporting.py:155: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   view = view.applymap(_fmt)
# [20:08:04] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png_pretty_all] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage2_understanding\step_2_3_data_quality_assessment_y_percentiles.png (rows=2 cols=6)
# [20:08:04] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.quality_rules_utils_data - [numeric_cols] selected 7/8 numeric cols (excluded=['id'])
# [20:08:04] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:05] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_trq_measured.png
# [20:08:05] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:05] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_oat.png
# [20:08:05] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:05] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_mgt.png
# [20:08:05] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:06] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_pa.png
# [20:08:06] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:06] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_ias.png
# [20:08:06] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:06] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_np.png
# [20:08:06] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:07] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_x_ng.png
# [20:08:07] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:07] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_bar_y_faulty.png
# [20:08:07] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.quality_rules_utils_data - [numeric_cols] selected 1/3 numeric cols (excluded=['faulty', 'id'])
# [20:08:07] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding
# [20:08:07] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.plots_utils_reporting - Saved figure: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\figures\stage2_understanding\step_2_4_eda_hist_y_trq_margin.png
# [20:08:07] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage2_understanding_runner_stages - === STAGE 2 END [run_stage2] ===
