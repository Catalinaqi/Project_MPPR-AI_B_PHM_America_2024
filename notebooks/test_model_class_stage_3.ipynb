# %%
from pathlib import Path

# ---------- Root Path ----------------------------------------------
# Repository root from /notebooks
PROJECT_ROOT = Path.cwd().parent
print("PROJECT_ROOT:", PROJECT_ROOT.exists(), "| is:", PROJECT_ROOT)
# -------------------------------------------------------------------


# ---------- Sub Paths ----------
OUT_ROOT = PROJECT_ROOT / "out" # Directory for outputs
print("OUT_ROOT:", OUT_ROOT.exists(), "| is:", OUT_ROOT)
CONFIG_ROOT = PROJECT_ROOT / "config" # Directory for configuration
print("CONFIG_ROOT:", CONFIG_ROOT.exists(), "| is:", CONFIG_ROOT)

# ---------- Yaml Paths ----------
# Paths to specific YAML configuration files
pipeline_yaml_path = CONFIG_ROOT / "pipeline" / "classification_pipeline_config.yml"
print("pipeline_yaml_path exists?", pipeline_yaml_path.exists(), "| is:",pipeline_yaml_path)
# Path to dataset configuration YAML file
dataset_yaml_path = CONFIG_ROOT / "dataset" / "dataset_config.yml"
print("dataset_yaml_path exists?", dataset_yaml_path.exists(), "| is:",dataset_yaml_path)
# Out:
# PROJECT_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024
# OUT_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# CONFIG_ROOT: True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config
# pipeline_yaml_path exists? True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\pipeline\classification_pipeline_config.yml
# dataset_yaml_path exists? True | is: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\dataset\dataset_config.yml

# %%
#################################### Parte 0 — Logging

from phm_america_2024.core.logging_utils_core import build_log_file, init_logging


log_file = build_log_file(output_root=OUT_ROOT, run_name="classification_manual_run")
init_logging(log_file=log_file, level="DEBUG")
# Out:
# [21:20:19] [DEBUG] LOG_PHM_NORTH_AMERICA_2024 - Logging initialized. log_file=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\logs\classification_manual_run_20260211_212019.log level=DEBUG
# <Logger LOG_PHM_NORTH_AMERICA_2024 (DEBUG)>

# %%
# Parte 1 — Cargar configuración (dataset + pipeline) y resolver variables

from phm_america_2024.pipelines.pipeline_context import build_context

ctx = build_context(
    dataset_config_path=str(dataset_yaml_path),
    pipeline_config_path=str(pipeline_yaml_path),
    output_root=str(OUT_ROOT)
)

cfg = ctx.cfg
variables = ctx.variables
output_root = ctx.output_root

# quick check
variables["join_key"], variables["label_col"], variables["x_train_path"]
# Out:
# [21:20:21] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.config.load_loader_config - Loading YAML: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\dataset\dataset_config.yml
# [21:20:21] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.config.load_loader_config - Loading YAML: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\config\pipeline\classification_pipeline_config.yml
# [21:20:21] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.seeds_utils_core - Global seed set: 42
# [21:20:21] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.pipelines.pipeline_context - Context built. output_root=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out
# [21:20:21] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.pipelines.pipeline_context - Variables keys=['join_key', 'label_col', 'output_root', 'time_col', 'x_test_path', 'x_train_path', 'x_validation_path', 'y_train_path']
# ('id', 'faulty', 'data/raw/train/X_train.csv')

# %%
from phm_america_2024.stages.stage3_preparation_runner_stages import run_stage3

stage3_out = run_stage3(cfg, variables, output_root)

stage3_out["X_train"].shape, stage3_out["X_valid"].shape
# Out:
# [21:20:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - [run_stage2] params={"cfg":{"pipeline":{"name":"classification_pipeline","objective":"End-to-end CRISP-ML pipeline for supervised classification (categorical target). Stages 2→5. Generates report artifacts (PNG/JSON) and persists trained models.\n","task":"classification","variables":{"join_key":"id","label_col":"faulty","time_col":"${time_col}","x_test_path":"data/raw/test/X_test.csv","x_train_path":"data/raw/train/X_train.csv","x_validation_path":"data/raw/validation/X_validation.csv","y_train_path":"data/raw/train/Y_train.csv"}},"runtime":{"output_root":"out","overwrite_artifacts":true,"random_seed":42},"stages":{"stage2_understanding":{"dataset_input":{"csv_params":{"decimal":".","encoding":"utf-8","low_memory":false,"sep":","},"labels_input":{"path":"data/raw/train/Y_train.csv","source_type":"csv"},"path":"data/raw/train/X_train.csv","read_strategy":{"chunk_size":200000,"mode":"full","random_state":42,"sample_rows":200000},"source_type":"csv"},"enabled":true,"objective":"Load CSV + describe structure + data quality assessment + EDA. Stage 2 MUST NOT modify data (report-only).\n","output_policy":{"align":"left","dpi":150,"figures_dir":"figures/stage2_understanding","float_fmt":"{:.3f}","max_rows":60,"save_all_as_png":true,"tables_png_dir":"tables_png/stage2_understanding"},"steps":{"step_2_1_data_acquisition":{"enabled":true,"methods":{"load_csv":{"enabled":true,"params":{"infer_datetime":false,"parse_dates":[]}}},"name":"step_2_1_data_acquisition","technique":"data_acquisition"},"step_2_2_describe_data":{"enabled":true,"name":"step_2_2_describe_data","techniques":{"descriptive_statistics":{"enabled":true,"methods":{"describe":{"enabled":true,"params":{"include":"all","numeric_only":false}},"min_max_mean_std":{"enabled":true,"params":{"numeric_only":true}}}},"schema_inspection":{"enabled":true,"methods":{"cardinality_count":{"enabled":true,"params":{"max_unique_to_report":50}},"dtype_analysis":{"enabled":true},"null_count":{"enabled":true}}}}},"step_2_3_data_quality_assessment":{"enabled":true,"methods":{"duplicate_detection":{"enabled":true,"params":{"keep":"first","subset":null}},"inconsistency_checks":{"enabled":false,"params":{"on_fail":"report_only","rules_file":"config/rules/logic_quality_rules_config.yml"}},"missing_analysis":{"enabled":true,"params":{"show_top_columns":30}},"outlier_detection":{"enabled":true,"params":{"iqr_k":1.5,"max_columns":30,"method":"iqr","numeric_only":true,"zscore_threshold":3.0}},"percentile_analysis":{"enabled":true,"params":{"columns":["pa"],"percentiles":[0.01,0.05,0.95,0.99,0.999]}},"range_validation":{"enabled":false,"params":{"on_fail":"report_only","rules_file":"config/rules/ranges_quality_rules_config.yml"}}},"name":"step_2_3_data_quality_assessment","technique":"data_quality_assessment"},"step_2_4_eda":{"enabled":true,"methods":{"boxplots":{"enabled":true,"params":{"max_columns":20,"numeric_only":true}},"correlation_matrix":{"enabled":true,"params":{"max_columns":30,"method":"pearson","numeric_only":true}},"histograms":{"enabled":true,"params":{"bins":30,"max_columns":20,"numeric_only":true}},"pca_exploratory":{"enabled":false,"params":{"n_components":2,"numeric_only":true,"sample_rows":20000}},"scatter_matrix":{"enabled":false,"params":{"max_columns":8,"numeric_only":true,"sample_rows":10000}}},"name":"step_2_4_eda","technique":"eda"}}},"stage3_preparation":{"enabled":true,"objective":"Prepare data for classification: selection + cleaning + transformations + (optional integration) + split + formatting. Generates artifacts.\n","output_policy":{"figures_dir":"figures/stage3_preparation","save_all_as_png":true,"tables_png_dir":"tables_png/stage3_preparation"},"steps":{"step_3_1_data_selection":{"enabled":true,"techniques":{"dataset_definition":{"enabled":false,"methods":{"drop_technical_columns":{"enabled":false,"params":{"patterns":["uuid","log"]}},"manual_include_exclude":{"ena ...
# [21:20:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - === STAGE 3 START [run_stage3] ===
# [21:20:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Stage3 resolved paths: x_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv (exists=True) y_path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv (exists=True)
# [21:20:26] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\X_train.csv mode=full
# [21:20:27] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(full): shape=(742625, 8)
# [21:20:27] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv: path=K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\data\raw\train\Y_train.csv mode=full
# [21:20:27] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - read_csv(full): shape=(742625, 3)
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.data.load_utils_data - join_x_y: join_key=id before=((742625, 8), (742625, 3)) after=(742625, 10)
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Dropping column after join: trq_margin
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Dropping column after join: id
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - [run_stage3] 3.1 remove_constant_features cfg={'enabled': True, 'params': {'threshold_unique': 1}}
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - [run_stage3] applying remove_constant_features(threshold_unique=1)
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.selection_service_features - [remove_constant_features] start | threshold_unique=1
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.selection_service_features - [remove_constant_features] no constant features found.
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [build_before_after_tables] step=3.1_remove_constant_features | removed=0 | added=0
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - [run_stage3] 3.1 remove_duplicate_features cfg={'enabled': True, 'params': {'strategy': 'exact'}}
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - [run_stage3] applying remove_duplicate_features(strategy=exact)
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.selection_service_features - [remove_duplicate_features] start | strategy=exact
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.selection_service_features - [remove_duplicate_features] no duplicate features found.
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.selection_service_features - [remove_duplicate_features] end | removed=0
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.tables_utils_reporting - [build_before_after_tables] step=3.1_remove_duplicate_features | removed=0 | added=0
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage3_preparation
# [21:20:28] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage3_preparation\stage3_step3_1_feature_selection_kpi.png (rows=2 cols=7)
# [21:20:28] [DEBUG] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.core.helpers_utils_core - ensure_dir: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage3_preparation
# [21:20:29] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.reporting.artifacts_service_reporting - [save_table_png] saved table: K:\00_Code\Manutenzione\Project_MPPR-AI_B_PHM_America_2024\out\tables_png\stage3_preparation\stage3_step3_1_feature_selection_changes.png (rows=2 cols=3)
# [21:20:29] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.split_service_features - split_holdout: train=(594100, 8) valid=(148525, 8) label=faulty stratify=True
# [21:20:29] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.features.transforms_service_features - Built numeric preprocessor: imputer=median scaling=standard features=7
# [21:20:29] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - Stage3 outputs: X_train=(594100, 7) y_train=(594100,) X_valid=(148525, 7) y_valid=(148525,) features=7
# [21:20:29] [INFO] LOG_PHM_NORTH_AMERICA_2024.phm_america_2024.stages.stage3_preparation_runner_stages - === STAGE 3 END [run_stage3] ===
# ((594100, 7), (148525, 7))
